# %% [markdown]
# <a href="https://colab.research.google.com/github/UniVR-DH/ADHLab/blob/main/lecture05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Testing Named Entity Recognition
#
# We will use the Spacy Library:
# https://spacy.io/usage/spacy-101

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1m_EMdnI5C826kgqK7r5vB4TXnB0-Wq7W" alt="Intestazione con loghi istituzionali" width="525"/>
#
# | Docente      | Insegnamento | Anno Accademico    |
# | :---        |    :----   |          ---: |
# | Matteo Lissandrini      | Laboratorio Avanzato di Informatica Umanistica       | 2024/2025   |

# %% [markdown]
# ## Usual install and basic imports

# %%
# %pip install wikipedia-api
# %pip install spacy==3.7.0
# Out:
# Requirement already satisfied: wikipedia-api in /usr/local/lib/python3.12/dist-packages (0.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from wikipedia-api) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->wikipedia-api) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->wikipedia-api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->wikipedia-api) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->wikipedia-api) (2025.11.12)
# Requirement already satisfied: spacy==3.7.0 in /usr/local/lib/python3.12/dist-packages (3.7.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (3.0.12)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (0.9.4)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (2.11.10)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from spacy==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.12/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy==3.7.0) (1.3.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.12/dist-packages (from pathy>=0.10.0->spacy==3.7.0) (0.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.0) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.0) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.0) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.7.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.7.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.7.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.7.0) (2025.11.12)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.12/dist-packages (from thinc<8.3.0,>=8.1.8->spacy==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.3.0,>=8.1.8->spacy==3.7.0) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.12/dist-packages (from typer<0.10.0,>=0.3.0->spacy==3.7.0) (8.3.1)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.4.0,>=0.1.0->spacy==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy==3.7.0) (3.0.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy==3.7.0) (1.3.1)

# %%
# !pip install pdfx
# Out:
# Requirement already satisfied: pdfx in /usr/local/lib/python3.12/dist-packages (1.4.1)
# Requirement already satisfied: pdfminer.six==20201018 in /usr/local/lib/python3.12/dist-packages (from pdfx) (20201018)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfx) (4.0.0)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20201018->pdfx) (43.0.3)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20201018->pdfx) (2.4.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography->pdfminer.six==20201018->pdfx) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography->pdfminer.six==20201018->pdfx) (2.23)

# %%
import spacy
from spacy import displacy
# Load module for english
nlp = spacy.load("en_core_web_sm")
# More options here: https://spacy.io/models/en
# Out:
# /usr/local/lib/python3.12/dist-packages/spacy/util.py:910: UserWarning: [W095] Model 'en_core_web_sm' (3.8.0) was trained with spaCy v3.8.0 and may not be 100% compatible with the current version (3.7.0). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
import pdfx

## Download a PDF and put it in your Files folder
## You can also use WGET command or the requests libary (see other notebooks) to download directly

# Assume you have downloaded the file from: https://dl.acm.org/doi/pdf/10.1145/3546954
pdf = pdfx.PDFx("3546954.pdf")

pdf

# %%
text = pdf.get_text()
text
# Out:
# 'DOI:10.1145/3546954 \n\nhttps://cacm.acm.org/blogs/blog-cacm\n\nChanging the Nature \nof AI Research\n\nSubbarao Kambhampati considers how artificial intelligence \nmay be straying from its roots.\n\nSubbarao \nKambhampati \nAI as (an Ersatz) \nNatural Science?\nhttps://bit.ly/3Rcf5NW\nJune 8, 2022\nIn  many  ways,  we  are  living  in  quite \na  wondrous  time  for  artificial  intel-\nligence  (AI),  with  every  week  bring-\ning  some  awe-inspiring  feat  in  yet \nanother  tacit  knowledge  (https://bit.\nly/3qYrAOY)  task  that  we  were  sure \nwould  be  out  of  reach  of  computers \nfor  quite  some  time  to  come.  Of  par-\nticular  recent  interest  are  the  large \nlearned  systems  based  on  trans-\nformer  architectures  that  are  trained \nwith  billions  of  parameters  over \nmassive  Web-scale  multimodal  cor-\npora.  Prominent  examples  include \nlarge  language  models  (https://bit.\nly/3iGdekA) like GPT3 and PALM that \nrespond  to  free-form  text  prompts, \nand \nlike \nlanguage/image  models \nDALL-E  and  Imagen  that  can  map \ntext prompts to photorealistic images \n(and even those with claims to gener-\nal behaviors, such as GATO) .\n\nThe  emergence  of  these \n\nlarge \nlearned  models  is  also  changing  the \nnature  of  AI  research  in  fundamen-\n\ntal  ways.  Just  the  other  day,  some  re-\nsearchers  were  playing  with  DALL-E \nand thought that it seems to have de-\nveloped  a  secret  language  of  its  own \n(https://bit.ly/3ahH1Py)  which,  if  we \ncan  master,  might  allow  us  to  inter-\nact  with  it  better.  Other  researchers \nfound  that  GPT3’s  responses  to  rea-\nsoning questions can be improved by \nadding certain seemingly magical in-\ncantations to the prompt (https://bit.\nly/3aelxmI),  the  most  prominent  of \nthese being “Let’s think step by step.” \nIt  is  almost  as  if  the  large  learned \nmodels  like  GPT3  and  DALL-E  are \nalien  organisms  whose  behavior  we \nare trying to decipher.\n\nThis  is  certainly  a  strange  turn  of \nevents  for  AI.  Since  its  inception,  AI \nhas  existed  in  the  no-man’s  land  be-\ntween  engineering  (which  aims  at \ndesigning  systems  for  specific  func-\ntions),  and  “Science”  (which  aims  to \ndiscover  the  regularities  in  naturally \noccurring  phenomena).  The  science \npart  of  AI  came  from  its  original  pre-\ntensions  to  provide  insights  into  the \nnature of (human) intelligence, while \nthe  engineering  part  came  from  a  fo-\ncus  on  intelligent  function  (get  com-\nputers  to  demonstrate  intelligent  be-\n\nhavior)  rather  than  on  insights  about \nnatural intelligence.\n\nThis  situation  is  changing  rapid-\nly–especially  as  AI  is  becoming  syn-\nonymous  with  large  learned  models. \nSome  of  these  systems  are  coming  to \na point where we not only do not know \nhow the models we trained are able to \nshow specific capabilities, we are very \nmuch in the dark even about what ca-\npabilities they might have (PALM’s al-\nleged capability of  “explaining jokes” \n—https://bit.ly/3yJk1m4— is a case in \npoint).  Often,  even  their  creators  are \ncaught  off  guard  by  things  these  sys-\ntems  seem  capable  of  doing.  Indeed, \nprobing  these  systems  to  get  a  sense \nof the scope of their “emergent behav-\niors”  has  become  quite  a  trend  in  AI \nresearch of late.\n\nGiven  this  state  of  affairs,  it  is  in-\ncreasingly clear that at least part of AI is \nstraying firmly away from its “engineer-\ning”  roots.  It  is  increasingly  hard  to \nconsider large learned systems as “de-\nsigned” in the traditional sense of the \nword, with a specific purpose in mind. \nAfter all, we don’t go around saying we \nare “designing” our kids (seminal work \nand  gestation  notwithstanding).  Be-\nsides,  engineering  disciplines  do  not \n\n8    COM M UNICATIO NS  O F  TH E ACM  |  SEPTEMBER 2022  |  VOL. 65  |  NO. 9\n\nFollow us o ...

# %%
doc = nlp(text)

# %%
import pandas as pd

cols = ("text", "lemma", "POS", "explain", "stopword")
rows = []

for t in doc:
    row = [t.text, t.lemma_, t.pos_, spacy.explain(t.pos_), t.is_stop]
    rows.append(row)

df = pd.DataFrame(rows, columns=cols)
df
# Out:
#                                       text  \
# 0                      DOI:10.1145/3546954
# 1                                     \n\n
# 2     https://cacm.acm.org/blogs/blog-cacm
# 3                                     \n\n
# 4                                 Changing
# ...                                    ...
# 2499
# 2500                                   ACM
# 2501
# 2502                                     9
# 2503                                 \n\n
#
#
#                                      lemma    POS      explain  stopword
# 0                      DOI:10.1145/3546954  PROPN  proper noun     False
# 1                                     \n\n  SPACE        space     False
# 2     https://cacm.acm.org/blogs/blog-cacm  PROPN  proper noun     False
# 3                                     \n\n  SPACE        space     False
# 4                                   change   VERB         verb     False
# ...                                    ...    ...          ...       ...
# 2499                                        SPACE        space     False
# 2500                                   ACM  PROPN  proper noun     False
# 2501                                        SPACE        space     False
# 2502                                     9    NUM      numeral     False
# 2503                                 \n\n
#   SPACE        space     False
#
# [2504 rows x 5 columns]

# %%
import string
import requests
import numpy as np
import regex as re
from collections import Counter

punct_regex = re.compile('[{}]'.format(re.escape(string.punctuation))) # Regex matching any punctuation
space_regex = re.compile(' +') # Regex matching whitespace

# %%
for label in nlp.get_pipe('ner').labels:
    print(f"{label}: {spacy.explain(label)}")
# Out:
# CARDINAL: Numerals that do not fall under another type
# DATE: Absolute or relative dates or periods
# EVENT: Named hurricanes, battles, wars, sports events, etc.
# FAC: Buildings, airports, highways, bridges, etc.
# GPE: Countries, cities, states
# LANGUAGE: Any named language
# LAW: Named documents made into laws.
# LOC: Non-GPE locations, mountain ranges, bodies of water
# MONEY: Monetary values, including unit
# NORP: Nationalities or religious or political groups
# ORDINAL: "first", "second", etc.
# ORG: Companies, agencies, institutions, etc.
# PERCENT: Percentage, including "%"
# PERSON: People, including fictional
# PRODUCT: Objects, vehicles, foods, etc. (not services)
# QUANTITY: Measurements, as of weight or distance
# TIME: Times smaller than a day
# WORK_OF_ART: Titles of books, songs, etc.

# %% [markdown]
# ## Test the NER methods
#
# Read more here:
#
# -  https://spacy.io/usage/linguistic-features
# -  https://spacy.io/usage/visualizers

# %%
doc = nlp("Paris Hilton has three children with Mark")

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Paris Hilton 0 12 ORG
# three 17 22 CARDINAL
# Mark 37 41 PERSON

# %%
# We can render in a nice format our annotations
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris Hilton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  children with
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mark
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </div></span>

# %%
doc = nlp("The Hilton Paris  hotel welcomes this year more than 1640 guests")

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
displacy.render(doc, style="ent", jupyter=True)
# Out:
# Hilton 4 10 GPE
# Paris 11 16 GPE
# this year 33 42 DATE
# more than 1640 43 57 CARDINAL
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hilton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#   hotel welcomes
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 1640
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  guests</div></span>

# %%
doc = nlp("Hilton Paris: Born in New York City, and raised there and in Los Angeles ")

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
displacy.render(doc, style="ent", jupyter=True)
# Out:
# Hilton 0 6 GPE
# Paris 7 12 GPE
# New York City 22 35 GPE
# Los Angeles 61 72 GPE
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hilton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# : Born in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and raised there and in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Los Angeles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  </div></span>

# %%
# Longer document
doc = nlp("""
Citing high fuel prices, United Airlines said Friday it has increased fares by $6
per round trip on flights to some cities also served by lower-cost carriers.
American Airlines, a unit of AMR Corp., immediately matched the move,
spokesman Tim Wagner said.
""")

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)

displacy.render(doc, style="ent", jupyter=True)
# Out:
# United Airlines 26 41 ORG
# Friday 47 53 DATE
# 6 81 82 MONEY
# American Airlines 160 177 ORG
# AMR Corp. 189 198 ORG
# Tim Wagner 240 250 PERSON
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br>Citing high fuel prices,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     United Airlines
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  said
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  it has increased fares by $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# <br>per round trip on flights to some cities also served by lower-cost carriers.<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American Airlines
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a unit of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AMR Corp.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , immediately matched the move,<br>spokesman
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tim Wagner
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said.<br></div></span>

# %% [markdown]
# ## Goal:  Test how NER would work on Text from Alice in Wonderland and Aesop's Fables

# %%
def get_pages(book_text):
  """
  Function that given  the book text returns a list of pages
  """
  _pages = [ _page.strip() for _page in book_text.split("\n\r\n\r\n\r")] # pages are divided by multiple newlines
  _pages = [ space_regex.sub(' ', page).strip() for page in _pages ]
  _pages = [ space_regex.sub(' ', " ".join(page.splitlines())) for page in _pages ]
  _pages = [ _page for _page in _pages if _pages != '' ]

  return _pages

# %%
# request the raw text of Alice in Wonderland
r = requests.get(r'https://ia801604.us.archive.org/6/items/alicesadventures19033gut/19033.txt')
alice = r.text

alice_pages = get_pages(alice)


r = requests.get(r'https://ia600906.us.archive.org/29/items/aesopsfablesanew11339gut/11339.txt')
fables = r.text

fables_pages = get_pages(fables)

# %%
test_page = alice_pages[16]
doc = nlp(test_page)
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">VII--A
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MAD TEA-PARTY
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  There was a table set out under a tree in front of the house, and
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the March Hare
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  and the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hatter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  were having tea at it; a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dormouse
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  was sitting between them, fast asleep. The table was a large one, but the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  were all crowded together at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  corner of it. &quot;No room! No room!&quot; they cried out when they saw
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  coming. &quot;There's _plenty_ of room!&quot; said
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  indignantly, and she sat down in a large arm-chair at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  end of the table. The
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hatter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  opened his eyes very wide on hearing this, but all he said was &quot;Why is a raven like a writing-desk?&quot; &quot;I'm glad they've begun asking riddles--I believe I can guess that,&quot; she added aloud. &quot;Do you mean that you think you can find out the answer to it?&quot; said the March Hare. &quot;Exactly so,&quot; said
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . &quot;Then you should say what you mean,&quot; the March Hare went on. &quot;I do,&quot;
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  hastily replied; &quot;at least--at least I mean what I say--that's the same thing, you know.&quot; &quot;You might just as well say,&quot; added the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dormouse
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , which seemed to be talking in its sleep, &quot;that 'I breathe when I sleep' is the same thing as 'I sleep when I breathe!'&quot; &quot;It _is_ the same thing with you,&quot; said the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hatter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and he poured a little hot tea upon its nose. The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dormouse
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  shook its head impatiently and said, without opening its eyes, &quot;Of course, of course; just what I was going to remark myself.&quot; [Illustration] &quot;Have you guessed the riddle yet?&quot; the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hatter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said, turning to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  again. &quot;No, I give it up,&quot;
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  replied. &quot;What's the answer?&quot; &quot;I haven't the slightest idea,&quot; said the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hatter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . &quot;Nor I,&quot; said the March Hare. Alice gave a weary sigh. &quot;I think you might do something better with the time,&quot; she said, &quot;than wasting it in asking riddles that have no answers.&quot; &quot;Take some more tea,&quot;
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the March Hare
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  said to
# <

# %% [markdown]
# ## Repeate the same for Aesop's Fables
#
# - Pick a few pages, test the NER
# - Does it find any entity at all? Does it miss some entities? What is going on?

# %%
test_page = fables_pages[16]
doc = nlp(test_page)
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">THE
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HORSE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  AND THE GROOM There was once a
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Groom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  who used to spend
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     long hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  clipping and combing the Horse of which he had charge, but who
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     daily
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  stole a portion of his allowance of oats, and sold it for his own profit. The Horse gradually got into worse and worse condition, and at last cried to the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Groom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , &quot;If you really want me to look sleek and well, you must comb me less and feed me more.&quot;</div></span>

# %%
test_page = fables_pages[13]
doc = nlp(test_page)
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">THE BAT AND THE WEASELS A
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  fell to the ground and was caught by a
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Weasel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and was just going to be killed and eaten when it begged to be let go. The
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Weasel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said he couldn't do that because he was an enemy of all birds on principle. &quot;Oh, but,&quot; said the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , &quot;I'm not a bird at all: I'm a mouse.&quot; &quot;So you are,&quot; said the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Weasel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , &quot;now I come to look at you&quot;; and he let it go. Some time after this the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was caught in just the same way by another
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Weasel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and, as before, begged for its life. &quot;No,&quot; said the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Weasel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , &quot;I never let a mouse go by any chance.&quot; &quot;But I'm not a mouse,&quot; said the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ; &quot;I'm a bird.&quot; &quot;Why, so you are,&quot; said the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Weasel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ; and he too let the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  go. Look and see which way the wind blows before you commit yourself.</div></span>

# %%
test_page = fables_pages[2]
doc = nlp(test_page)
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AESOP'S
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  FABLES A NEW TRANSLATION BY
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     V. S. VERNON JONES
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  WITH AN INTRODUCTION BY
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     G. K. CHESTERTON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  AND ILLUSTRATIONS BY
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ARTHUR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  RACKHAM 1912 EDITION</div></span>

# %% [markdown]
# **If you are curious about `entity linking` you can see this tutorial:**
#
# https://github.com/explosion/projects/blob/v3/tutorials/nel_emerson/notebooks/notebook_video.ipynb

# %% [markdown]
# ## Compute Frequencies of Entities in pages

# %% [markdown]
# ## Build an inverted index for named entities

# %% [markdown]
# ## Compute via majority voting the most likely type for a given named entity
#
# For example, should we say Weasel is a person or an org?

# %% [markdown]
# ## Extract named entities from a wikipedia page
